# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path to your dataset
base_dir = '/content/sample_data'

# Data augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% for validation
)

# Load training and validation data
train_data = datagen.flow_from_directory(
    base_dir,
    target_size=(224, 224),  # Resize images to model input size
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    base_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 493 images belonging to 4 classes.
# Found 122 images belonging to 4 classes.

# %%
from tensorflow.keras.applications import VGG16, ResNet50, MobileNetV2, InceptionV3
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D

# Example: Load a pre-trained model and fine-tune
def create_model(base_model):
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(len(train_data.class_indices), activation='softmax')  # Output layer
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Models
models = {
    "VGG16": create_model(VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))),
    "ResNet50": create_model(ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))),
    "MobileNetV2": create_model(MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))),
    "InceptionV3": create_model(InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))),
}

# Train models
history_dict = {}
for model_name, model in models.items():
    print(f"Training {model_name}...")
    history = model.fit(train_data, validation_data=val_data, epochs=10)
    history_dict[model_name] = history
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training VGG16...
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.2897 - loss: 4.2761 - val_accuracy: 0.3934 - val_loss: 1.1443
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 64s 482ms/step - accuracy: 0.3555 - loss: 1.1390 - val_accuracy: 0.3934 - val_loss: 1.1138
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 482ms/step - accuracy: 0.2837 - loss: 1.1275 - val_accuracy: 0.3279 - val_loss: 1.1398
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 503ms/step - accuracy: 0.3047 - loss: 1.1381 - val_accuracy: 0.4016 - val_loss: 1.0971
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.3820 - loss: 1.0937 - val_accuracy: 0.3934 - val_loss: 1.1158
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 498ms/step - accuracy: 0.4033 - loss: 1.1002 - val_accuracy: 0.4016 - val_loss: 1.0602
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 501ms/step - accuracy: 0.4583 - loss: 1.0473 - val_accuracy: 0.5574 - val_loss: 0.9469
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 512ms/step - accuracy: 0.5462 - loss: 0.9248 - val_accuracy: 0.5984 - val_loss: 0.8542
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 508ms/step - accuracy: 0.5852 - loss: 0.8295 - val_accuracy: 0.6311 - val_loss: 0.8600
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 495ms/step - accuracy: 0.7069 - loss: 0.6987 - val_accuracy: 0.7213 - val_loss: 0.7427
# Training ResNet50...
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 103s 3s/step - accuracy: 0.7856 - loss: 0.6912 - val_accuracy: 0.2787 - val_loss: 84.3497
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 345ms/step - accuracy: 0.9600 - loss: 0.1018 - val_accuracy: 0.2787 - val_loss: 15.3608
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - accuracy: 0.9551 - loss: 0.1738 - val_accuracy: 0.3934 - val_loss: 543.9660
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 363ms/step - accuracy: 0.9617 - loss: 0.1194 - val_accuracy: 0.3934 - val_loss: 686.9163
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 320ms/step - accuracy: 0.9703 - loss: 0.1168 - val_accuracy: 0.3934 - val_loss: 520.2836
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 361ms/step - accuracy: 0.9786 - loss: 0.0706 - val_accuracy: 0.3934 - val_loss: 612.8630
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.9212 - loss: 0.3173 - val_accuracy: 0.2787 - val_loss: 338581.9688
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 337ms/step - accuracy: 0.9043 - loss: 0.4031 - val_accuracy: 0.3934 - val_loss: 117450.2422
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.9460 - loss: 0.1952 - val_accuracy: 0.3934 - val_loss: 19244.9238
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - accuracy: 0.9460 - loss: 0.2624 - val_accuracy: 0.3934 - val_loss: 12857.3896
# Training MobileNetV2...
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.7635 - loss: 0.4904 - val_accuracy: 0.3689 - val_loss: 7.6096
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.9799 - loss: 0.0604 - val_accuracy: 0.3607 - val_loss: 24.5207
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9708 - loss: 0.1120 - val_accuracy: 0.3279 - val_loss: 28.3697
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.9892 - loss: 0.0565 - val_accuracy: 0.3279 - val_loss: 36.4478
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.9789 - loss: 0.0770 - val_accuracy: 0.3607 - val_loss: 34.8631
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.9688 - loss: 0.1244 - val_accuracy: 0.3361 - val_loss: 36.9600
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.9816 - loss: 0.0655 - val_accuracy: 0.3279 - val_loss: 43.2927
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9764 - loss: 0.1086 - val_accuracy: 0.3279 - val_loss: 24.1298
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.9974 - loss: 0.0249 - val_accuracy: 0.3443 - val_loss: 13.3070
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.9992 - loss: 0.0101 - val_accuracy: 0.3279 - val_loss: 30.1725
# Training InceptionV3...
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.7835 - loss: 0.5529 - val_accuracy: 0.3033 - val_loss: 18.1802
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 306ms/step - accuracy: 0.9392 - loss: 0.2256 - val_accuracy: 0.3279 - val_loss: 1454.0787
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - accuracy: 0.9591 - loss: 0.1291 - val_accuracy: 0.3279 - val_loss: 148.8775
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 257ms/step - accuracy: 0.9390 - loss: 0.2046 - val_accuracy: 0.3279 - val_loss: 15.9438
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9651 - loss: 0.1181 - val_accuracy: 0.3279 - val_loss: 50.1194
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9803 - loss: 0.0849 - val_accuracy: 0.3279 - val_loss: 72.3631
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.9691 - loss: 0.1393 - val_accuracy: 0.5492 - val_loss: 6.9064
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.9961 - loss: 0.0173 - val_accuracy: 0.8607 - val_loss: 0.5669
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9836 - loss: 0.0682 - val_accuracy: 0.5000 - val_loss: 6.5330
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - accuracy: 0.9777 - loss: 0.0592 - val_accuracy: 0.5820 - val_loss: 4.2279

# %%
import matplotlib.pyplot as plt

def plot_metrics(history, metric, title):
    plt.figure(figsize=(10, 6))
    for model_name, hist in history.items():
        plt.plot(hist.history[metric], label=f"{model_name} {metric.capitalize()}")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.show()


plot_metrics(history_dict, 'accuracy', 'Training Accuracy of Models')


plot_metrics(history_dict, 'loss', 'Training Loss of Models')

# %%
import pandas as pd

# Assuming test_data is loaded similarly as train_data
comparison = []

for model_name, model in models.items():
    test_loss, test_accuracy = model.evaluate(val_data)
    comparison.append({
        "Model": model_name,
        "Test Accuracy": test_accuracy,
        "Test Loss": test_loss
    })

comparison_df = pd.DataFrame(comparison)
print(comparison_df)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.6958 - loss: 0.7421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.3834 - loss: 12536.4385
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.3436 - loss: 29.7061
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.6036 - loss: 3.6924
#          Model  Test Accuracy     Test Loss
# 0        VGG16       0.721311      0.742743
# 1     ResNet50       0.393443  12857.389648
# 2  MobileNetV2       0.327869     30.172495
# 3  InceptionV3       0.581967      4.227926
